# %% [markdown]
# # Pull Odds for NBA Games from sportsdatabase

# %%
import nba_api.stats.endpoints as nba
import mysql.connector
from mysql.connector import errorcode
import config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dbname = 'nba'
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    db = dbname
)
cursor = cnx.cursor(buffered = True)

# %%
stmt = """SELECT * FROM nba.game_logs"""
cursor.execute(stmt)
games = cursor.fetchall()

# %%
field_names = [i[0] for i in cursor.description]
games = pd.DataFrame(games)
games.columns = field_names

# %%
games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        22017  1610612738               BOS          Boston Celtics
# 1        22017  1610612739               CLE     Cleveland Cavaliers
# 2        22017  1610612744               GSW   Golden State Warriors
# 3        22017  1610612745               HOU         Houston Rockets
# 4        22017  1610612766               CHA       Charlotte Hornets
# ...        ...         ...               ...                     ...
# 6187     22019  1610612753               ORL           Orlando Magic
# 6188     22019  1610612760               OKC   Oklahoma City Thunder
# 6189     22019  1610612757               POR  Portland Trail Blazers
# 6190     22019  1610612758               SAC        Sacramento Kings
# 6191     22019  1610612762               UTA               Utah Jazz
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  REB  AST  STL  \
# 0     0021700001  2017-10-17    BOS @ CLE  L  240   36  ...   46   24   11
# 1     0021700001  2017-10-17  CLE vs. BOS  W  240   38  ...   50   19    3
# 2     0021700002  2017-10-17  GSW vs. HOU  L  240   43  ...   41   34    5
# 3     0021700002  2017-10-17    HOU @ GSW  W  240   47  ...   43   28    9
# 4     0021700003  2017-10-18    CHA @ DET  L  240   29  ...   47   16    4
# ...          ...         ...          ... ..  ...  ...  ...  ...  ...  ...
# 6187  0021900634  2020-01-18    ORL @ GSW  L  240   39  ...   46   21    7
# 6188  0021900635  2020-01-18  OKC vs. POR  W  240   43  ...   48   25    5
# 6189  0021900635  2020-01-18    POR @ OKC  L  240   39  ...   40   11    7
# 6190  0021900636  2020-01-18    SAC @ UTA  L  240   42  ...   37   20    3
# 6191  0021900636  2020-01-18  UTA vs. SAC  W  240   43  ...   47   24    7
#
#       BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE             pk
# 0       4   12  24   99          -3                1  0021700001BOS
# 1       4   17  25  102           3                1  0021700001CLE
# 2       9   17  25  121          -1                1  0021700002GSW
# 3       5   13  16  122           1                1  0021700002HOU
# 4       3   17  15   90         -12                1  0021700003CHA
# ...   ...  ...  ..  ...         ...              ...            ...
# 6187    5   15  12   95         -14                1  0021900634ORL
# 6188    4   13  20  119          13                1  0021900635OKC
# 6189    7   12  28  106         -13                1  0021900635POR
# 6190    3   10  23  101         -22                1  0021900636SAC
# 6191    4   10  14  123          22                1  0021900636UTA
#
# [6192 rows x 30 columns]

# %%
vegas = pd.read_csv('vegas_info.csv', index_col=0)

# %%
vegas['team'].unique()
# Out:
# array(['Cavaliers', 'Celtics', 'Warriors', 'Rockets', 'Bucks',
#        'Grizzlies', 'Pelicans', 'Jazz', 'Nuggets', 'Kings', 'Magic',
#        'Heat', 'Mavericks', 'Hawks', 'Pacers', 'Nets', 'Pistons',
#        'Hornets', 'Spurs', 'Timberwolves', 'Suns', 'Trailblazers',
#        'Wizards', 'Seventysixers', 'Lakers', 'Clippers', 'Raptors',
#        'Bulls', 'Thunder', 'Knicks'], dtype=object)

# %% [markdown]
# ### Need to join tables to get game id in vegas dataframe by matching games first on date, then by team abbreviation

# %%
games.TEAM_ABBREVIATION.unique()
# Out:
# array(['BOS', 'CLE', 'GSW', 'HOU', 'CHA', 'DET', 'BKN', 'IND', 'MIA',
#        'ORL', 'PHI', 'WAS', 'MIL', 'MEM', 'NOP', 'ATL', 'DAL', 'DEN',
#        'UTA', 'MIN', 'SAS', 'PHX', 'POR', 'SAC', 'CHI', 'TOR', 'NYK',
#        'OKC', 'LAC', 'LAL'], dtype=object)

# %%
### Create map for team names in vegas df to convert them to team abbreviations used by the NBA
team_map = {'Cavaliers': 'CLE', 
            'Celtics': 'BOS', 
            'Warriors': 'GSW', 
            'Rockets': 'HOU', 
            'Bucks': 'MIL',
            'Grizzlies': 'MEM', 
            'Pelicans': 'NOP', 
            'Jazz': 'UTA', 
            'Nuggets': 'DEN', 
            'Kings': 'SAC', 
            'Magic': 'ORL',
            'Heat': 'MIA', 
            'Mavericks': 'DAL', 
            'Hawks': 'ATL', 
            'Pacers':'IND', 
            'Nets': 'BKN', 
            'Pistons': 'DET',
            'Hornets': 'CHA', 
            'Spurs': 'SAS', 
            'Timberwolves': 'MIN', 
            'Suns': 'PHX', 
            'Trailblazers': 'POR',
            'Wizards': 'WAS', 
            'Seventysixers': 'PHI', 
            'Lakers': 'LAL', 
            'Clippers': 'LAC', 
            'Raptors': 'TOR',
            'Bulls': 'CHI', 
            'Thunder': 'OKC', 
            'Knicks' : 'NYK'
    
}

# %%
vegas['team_abbreviation'] = vegas['team'].map(lambda x : team_map[x])

# %%
vegas['opposing_team_abbreviation'] = vegas['o:team'].map(lambda x : team_map[x])

# %%
vegas
# Out:
#           date          team  site        o:team  line  total  \
# 0     20171017     Cavaliers  home       Celtics  -3.5  212.5
# 1     20171017       Celtics  away     Cavaliers   3.5  212.5
# 2     20171017      Warriors  home       Rockets  -9.0  228.5
# 3     20171017       Rockets  away      Warriors   9.0  228.5
# 4     20171018       Celtics  home         Bucks  -2.0  206.0
# ...        ...           ...   ...           ...   ...    ...
# 7703  20200415        Knicks  away  Timberwolves     -      -
# 7704  20200415  Trailblazers  home      Clippers     -      -
# 7705  20200415      Clippers  away  Trailblazers     -      -
# 7706  20200415       Wizards  home        Pacers     -      -
# 7707  20200415        Pacers  away       Wizards     -      -
#
#      team_abbreviation opposing_team_abbreviation
# 0                  CLE                        BOS
# 1                  BOS                        CLE
# 2                  GSW                        HOU
# 3                  HOU                        GSW
# 4                  BOS                        MIL
# ...                ...                        ...
# 7703               NYK                        MIN
# 7704               POR                        LAC
# 7705               LAC                        POR
# 7706               WAS                        IND
# 7707               IND                        WAS
#
# [7708 rows x 8 columns]

# %% [markdown]
# ### Manipulate the data to get it in the same format as the game logs table

# %%
def convert_date(date):
    return date[:4] + '-' + date[4:6] + '-'+ date[6:]

# %%
vegas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7708 entries, 0 to 7707
# Data columns (total 8 columns):
# date                          7708 non-null int64
# team                          7708 non-null object
# site                          7708 non-null object
# o:team                        7708 non-null object
# line                          7708 non-null object
# total                         7708 non-null object
# team_abbreviation             7708 non-null object
# opposing_team_abbreviation    7708 non-null object
# dtypes: int64(1), object(7)
# memory usage: 542.0+ KB

# %%
vegas.date = vegas.date.astype('str')
vegas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7708 entries, 0 to 7707
# Data columns (total 8 columns):
# date                          7708 non-null object
# team                          7708 non-null object
# site                          7708 non-null object
# o:team                        7708 non-null object
# line                          7708 non-null object
# total                         7708 non-null object
# team_abbreviation             7708 non-null object
# opposing_team_abbreviation    7708 non-null object
# dtypes: object(8)
# memory usage: 542.0+ KB

# %%
vegas['match_date'] = vegas['date'].apply(lambda x : convert_date(x))

# %%
vegas
# Out:
#           date          team  site        o:team  line  total  \
# 0     20171017     Cavaliers  home       Celtics  -3.5  212.5
# 1     20171017       Celtics  away     Cavaliers   3.5  212.5
# 2     20171017      Warriors  home       Rockets  -9.0  228.5
# 3     20171017       Rockets  away      Warriors   9.0  228.5
# 4     20171018       Celtics  home         Bucks  -2.0  206.0
# ...        ...           ...   ...           ...   ...    ...
# 7703  20200415        Knicks  away  Timberwolves     -      -
# 7704  20200415  Trailblazers  home      Clippers     -      -
# 7705  20200415      Clippers  away  Trailblazers     -      -
# 7706  20200415       Wizards  home        Pacers     -      -
# 7707  20200415        Pacers  away       Wizards     -      -
#
#      team_abbreviation opposing_team_abbreviation  match_date
# 0                  CLE                        BOS  2017-10-17
# 1                  BOS                        CLE  2017-10-17
# 2                  GSW                        HOU  2017-10-17
# 3                  HOU                        GSW  2017-10-17
# 4                  BOS                        MIL  2017-10-18
# ...                ...                        ...         ...
# 7703               NYK                        MIN  2020-04-15
# 7704               POR                        LAC  2020-04-15
# 7705               LAC                        POR  2020-04-15
# 7706               WAS                        IND  2020-04-15
# 7707               IND                        WAS  2020-04-15
#
# [7708 rows x 9 columns]

# %%
games_sub = games[['TEAM_ABBREVIATION', 'GAME_DATE', 'GAME_ID']]

# %%
games_sub
# Out:
#      TEAM_ABBREVIATION   GAME_DATE     GAME_ID
# 0                  BOS  2017-10-17  0021700001
# 1                  CLE  2017-10-17  0021700001
# 2                  GSW  2017-10-17  0021700002
# 3                  HOU  2017-10-17  0021700002
# 4                  CHA  2017-10-18  0021700003
# ...                ...         ...         ...
# 5393               WAS  2019-11-24  0021900237
# 5394               DEN  2019-11-24  0021900238
# 5395               PHX  2019-11-24  0021900238
# 5396               LAC  2019-11-24  0021900239
# 5397               NOP  2019-11-24  0021900239
#
# [5398 rows x 3 columns]

# %%
combined = pd.merge(left=vegas, right=games_sub, left_on=['team_abbreviation', 'match_date'], right_on=['TEAM_ABBREVIATION', 'GAME_DATE'])

# %%
combined.columns
# Out:
# Index(['date', 'team', 'site', 'o:team', 'line', 'total', 'team_abbreviation',
#        'opposing_team_abbreviation', 'match_date', 'TEAM_ABBREVIATION',
#        'GAME_DATE', 'GAME_ID'],
#       dtype='object')

# %%
cols = ['match_date', 'team_abbreviation', 'site', 'opposing_team_abbreviation', 'line', 'total', 'GAME_ID']

# %%
upload_df = combined[cols]
upload_df.columns
# Out:
# Index(['match_date', 'team_abbreviation', 'site', 'opposing_team_abbreviation',
#        'line', 'total', 'GAME_ID'],
#       dtype='object')

# %%
cols =['date', 'team', 'site', 'oteam', 'line', 'total', 'game_id']
upload_df.columns = cols
upload_df
# Out:
#             date team  site oteam  line  total     game_id
# 0     2017-10-17  CLE  home   BOS  -3.5  212.5  0021700001
# 1     2017-10-17  BOS  away   CLE   3.5  212.5  0021700001
# 2     2017-10-17  GSW  home   HOU  -9.0  228.5  0021700002
# 3     2017-10-17  HOU  away   GSW   9.0  228.5  0021700002
# 4     2017-10-18  BOS  home   MIL  -2.0  206.0  0021700007
# ...          ...  ...   ...   ...   ...    ...         ...
# 5393  2019-11-24  PHX  away   DEN  11.0  214.5  0021900238
# 5394  2019-11-24  HOU  home   DAL  -5.5  232.0  0021900235
# 5395  2019-11-24  DAL  away   HOU   5.5  232.0  0021900235
# 5396  2019-11-24  WAS  home   SAC  -2.5  233.0  0021900237
# 5397  2019-11-24  SAC  away   WAS   2.5  233.0  0021900237
#
# [5398 rows x 7 columns]

# %%
upload_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5398 entries, 0 to 5397
# Data columns (total 7 columns):
# date       5398 non-null object
# team       5398 non-null object
# site       5398 non-null object
# oteam      5398 non-null object
# line       5398 non-null object
# total      5398 non-null object
# game_id    5398 non-null object
# dtypes: object(7)
# memory usage: 337.4+ KB

# %%
upload_df.line = upload_df.line.astype('float')
upload_df.total = upload_df.total.astype('float')
# Out:
# /Users/marshall132/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
upload_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5398 entries, 0 to 5397
# Data columns (total 7 columns):
# date       5398 non-null object
# team       5398 non-null object
# site       5398 non-null object
# oteam      5398 non-null object
# line       5398 non-null float64
# total      5398 non-null float64
# game_id    5398 non-null object
# dtypes: float64(2), object(5)
# memory usage: 337.4+ KB

# %%
tables = {}
tables['vegas'] = (
    "CREATE TABLE vegas ("
    " date varchar(100),"
    " team varchar(3),"
    " site varchar(4),"
    " oteam varchar(3),"
    " line float,"
    " total float,"
    " game_id varchar(100)"
    ") ENGINE=InnoDB")

# %%
for table_name in tables:
    table_description = tables[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table vegas: OK

# %%
def insert_into_table(table, df):
    import numpy as np
    
    ### Get column names from table
    stmt = "SELECT * from nba.{}".format(table)
    cursor.execute(stmt)
    scores = cursor.fetchall()
    
    field_names = [i[0] for i in cursor.description]
    
    reordered_df = df[field_names]
    ## replace nan with none for SQL
    reordered_df.replace({np.nan: None}, inplace = True)
    
    ## build insert statement using properly ordered columns
    cols_insert = ''
    str_insert = ''
    for col in reordered_df.columns:
        cols_insert += col + ', '
        str_insert += '%s, '
    cols_insert = cols_insert.strip(', ')
    str_insert = str_insert.strip(', ')
    
    ## extract values from dataframe as tuples
    
    stats = [tuple(row) for row in reordered_df.values]
    
    # Insert and commit all the player stats
    insert_statement = """INSERT INTO nba.{} ({}) VALUES ({})""".format(table, cols_insert, str_insert)
    cursor.executemany(insert_statement, stats)
    cnx.commit()

# %%
upload_df
# Out:
#             date team  site oteam  line  total     game_id
# 0     2017-10-17  CLE  home   BOS  -3.5  212.5  0021700001
# 1     2017-10-17  BOS  away   CLE   3.5  212.5  0021700001
# 2     2017-10-17  GSW  home   HOU  -9.0  228.5  0021700002
# 3     2017-10-17  HOU  away   GSW   9.0  228.5  0021700002
# 4     2017-10-18  BOS  home   MIL  -2.0  206.0  0021700007
# ...          ...  ...   ...   ...   ...    ...         ...
# 5393  2019-11-24  PHX  away   DEN  11.0  214.5  0021900238
# 5394  2019-11-24  HOU  home   DAL  -5.5  232.0  0021900235
# 5395  2019-11-24  DAL  away   HOU   5.5  232.0  0021900235
# 5396  2019-11-24  WAS  home   SAC  -2.5  233.0  0021900237
# 5397  2019-11-24  SAC  away   WAS   2.5  233.0  0021900237
#
# [5398 rows x 7 columns]

# %%
insert_into_table('vegas', upload_df)

# %% [markdown]
# ### Update with new games for 2019 season

# %%
from sports_database_scrape import pull_nba_lines

# %%
lines_2019 = pull_nba_lines('2019')

# %%
lines_2019['team_abbreviation'] = lines_2019['team'].map(lambda x : team_map[x])

lines_2019['opposing_team_abbreviation'] = lines_2019['o:team'].map(lambda x : team_map[x])

# %%
lines_2019.date = lines_2019.date.astype('str')
lines_2019['match_date'] = lines_2019['date'].apply(lambda x : convert_date(x))

lines_2019[lines_2019['date']=='20200119']
# Out:
#           date     team  site   o:team  line  total team_abbreviation  \
# 1272  20200119  Nuggets  home   Pacers   0.0  213.5               DEN
# 1273  20200119   Pacers  away  Nuggets   0.0  213.5               IND
# 1274  20200119    Spurs  home     Heat   1.0  221.0               SAS
# 1275  20200119     Heat  away    Spurs  -1.0  221.0               MIA
#
#      opposing_team_abbreviation  match_date
# 1272                        IND  2020-01-19
# 1273                        DEN  2020-01-19
# 1274                        MIA  2020-01-19
# 1275                        SAS  2020-01-19

# %%
stmt = """SELECT * FROM nba.game_logs"""
cursor.execute(stmt)
games = cursor.fetchall()

# %%
field_names = [i[0] for i in cursor.description]
games = pd.DataFrame(games)
games.columns = field_names

# %%
games_sub = games[['TEAM_ABBREVIATION', 'GAME_DATE', 'GAME_ID']]

# %%
combined = pd.merge(left=lines_2019, right=games_sub, left_on=['team_abbreviation', 'match_date'], right_on=['TEAM_ABBREVIATION', 'GAME_DATE'])

# %%
combined.columns
# Out:
# Index(['date', 'team', 'site', 'o:team', 'line', 'total', 'team_abbreviation',
#        'opposing_team_abbreviation', 'match_date', 'TEAM_ABBREVIATION',
#        'GAME_DATE', 'GAME_ID'],
#       dtype='object')

# %%
cols = ['match_date', 'team_abbreviation', 'site', 'opposing_team_abbreviation', 'line', 'total', 'GAME_ID']

# %%
upload_df = combined[cols]
upload_df.columns
# Out:
# Index(['match_date', 'team_abbreviation', 'site', 'opposing_team_abbreviation',
#        'line', 'total', 'GAME_ID'],
#       dtype='object')

# %%
cols =['date', 'team', 'site', 'oteam', 'line', 'total', 'game_id']
upload_df.columns = cols
upload_df
# Out:
#             date team  site oteam  line  total     game_id
# 0     2019-10-22  LAC  home   LAL   1.5  224.0  0021900002
# 1     2019-10-22  LAL  away   LAC  -1.5  224.0  0021900002
# 2     2019-10-22  TOR  home   NOP  -7.0  231.5  0021900001
# 3     2019-10-22  NOP  away   TOR   7.0  231.5  0021900001
# 4     2019-10-23  MIA  home   MEM  -8.0  214.0  0021900007
# ...          ...  ...   ...   ...   ...    ...         ...
# 1267  2020-01-18  POR  away   OKC   6.5  220.0  0021900635
# 1268  2020-01-18  MIN  home   TOR   5.0  224.5  0021900632
# 1269  2020-01-18  TOR  away   MIN  -5.0  224.5  0021900632
# 1270  2020-01-18  GSW  home   ORL   4.5  212.0  0021900634
# 1271  2020-01-18  ORL  away   GSW  -4.5  212.0  0021900634
#
# [1272 rows x 7 columns]

# %%
sub_2019 = upload_df[upload_df['date'] > '2019-11-24']

# %%
sub_2019
# Out:
#            date team  site oteam   line  total     game_id
# 468  2019-11-24  LAC  home   NOP  -13.0  233.5  0021900239
# 469  2019-11-24  NOP  away   LAC   13.0  233.5  0021900239
# 470  2019-11-24  NYK  home   BKN    2.5  214.5  0021900236
# 471  2019-11-24  BKN  away   NYK   -2.5  214.5  0021900236
# 472  2019-11-24  DEN  home   PHX  -11.0  214.5  0021900238
# 473  2019-11-24  PHX  away   DEN   11.0  214.5  0021900238
# 474  2019-11-24  HOU  home   DAL   -5.5  232.0  0021900235
# 475  2019-11-24  DAL  away   HOU    5.5  232.0  0021900235
# 476  2019-11-24  WAS  home   SAC   -2.5  233.0  0021900237
# 477  2019-11-24  SAC  away   WAS    2.5  233.0  0021900237

# %%
insert_into_table('vegas', sub_2019)

# %%
def upload_vegas(year, day):
    
    lines_2019 = pull_nba_lines(year)
    
    lines_2019['team_abbreviation'] = lines_2019['team'].map(lambda x : team_map[x])

    lines_2019['opposing_team_abbreviation'] = lines_2019['o:team'].map(lambda x : team_map[x])
    
    lines_2019.date = lines_2019.date.astype('str')
    lines_2019['match_date'] = lines_2019['date'].apply(lambda x : convert_date(x))

    stmt = """SELECT * FROM nba.game_logs"""
    cursor.execute(stmt)
    games = cursor.fetchall()
    
    field_names = [i[0] for i in cursor.description]
    games = pd.DataFrame(games)
    games.columns = field_names
    
    games_sub = games[['TEAM_ABBREVIATION', 'GAME_DATE', 'GAME_ID']]
    
    combined = pd.merge(left=lines_2019, right=games_sub, left_on=['team_abbreviation', 'match_date'], right_on=['TEAM_ABBREVIATION', 'GAME_DATE'])
    
    cols = ['match_date', 'team_abbreviation', 'site', 'opposing_team_abbreviation', 'line', 'total', 'GAME_ID']
    
    upload_df = combined[cols]
    
    cols =['date', 'team', 'site', 'oteam', 'line', 'total', 'game_id']
    upload_df.columns = cols
    
    sub_2019 = upload_df[upload_df['date'] == day]
    
    insert_into_table('vegas', sub_2019)
    
    print('Lines and over unders inserted into the vegas table')

# %%
upload_vegas('2019','2020-01-20')
# Out:
# Lines and over unders inserted into the vegas table
