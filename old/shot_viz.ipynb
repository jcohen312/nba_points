# %%
import plotly
# import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import mysql.connector
import config
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dbname = 'nba'
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    db = dbname
)
cursor = cnx.cursor(buffered = True)

# %%
stmt = "SELECT * from nba.shot_chart"
cursor.execute(stmt)
scores = cursor.fetchall()

field_names = [i[0] for i in cursor.description]
shots = pd.DataFrame(scores)
shots.columns = field_names

# %%
shots.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM'],
#       dtype='object')

# %%
shots[shots['PLAYER_NAME'] == 'Ben Simmons']
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  PLAYER_NAME  \
# 403975  Shot Chart Detail  0021700006             33    1627732  Ben Simmons
# 403976  Shot Chart Detail  0021700006             47    1627732  Ben Simmons
# 403977  Shot Chart Detail  0021700006             77    1627732  Ben Simmons
# 403978  Shot Chart Detail  0021700006            182    1627732  Ben Simmons
# 403979  Shot Chart Detail  0021700006            187    1627732  Ben Simmons
# ...                   ...         ...            ...        ...          ...
# 406069  Shot Chart Detail  0021900230             73    1627732  Ben Simmons
# 406070  Shot Chart Detail  0021900230            301    1627732  Ben Simmons
# 406071  Shot Chart Detail  0021900230            394    1627732  Ben Simmons
# 406072  Shot Chart Detail  0021900230            442    1627732  Ben Simmons
# 406073  Shot Chart Detail  0021900230            452    1627732  Ben Simmons
#
#            TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 403975  1610612755  Philadelphia 76ers       1                  9
# 403976  1610612755  Philadelphia 76ers       1                  8
# 403977  1610612755  Philadelphia 76ers       1                  5
# 403978  1610612755  Philadelphia 76ers       2                 11
# 403979  1610612755  Philadelphia 76ers       2                 10
# ...            ...                 ...     ...                ...
# 406069  1610612755  Philadelphia 76ers       1                  5
# 406070  1610612755  Philadelphia 76ers       2                  2
# 406071  1610612755  Philadelphia 76ers       3                  8
# 406072  1610612755  Philadelphia 76ers       3                  3
# 406073  1610612755  Philadelphia 76ers       3                  3
#
#         SECONDS_REMAINING  ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE  \
# 403975                 44  ...      Center(C)  Less Than 8 ft.             3
# 403976                 28  ...      Center(C)  Less Than 8 ft.             1
# 403977                 54  ...  Right Side(R)         8-16 ft.             9
# 403978                 43  ...      Center(C)  Less Than 8 ft.             0
# 403979                 42  ...      Center(C)  Less Than 8 ft.             0
# ...                   ...  ...            ...              ...           ...
# 406069                 43  ...      Center(C)  Less Than 8 ft.             1
# 406070                 19  ...      Center(C)  Less Than 8 ft.             3
# 406071                 10  ...      Center(C)  Less Than 8 ft.             6
# 406072                 58  ...      Center(C)  Less Than 8 ft.             6
# 406073                 16  ...      Center(C)  Less Than 8 ft.             3
#
#        LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 403975   -18    26                   1               0   20171018  WAS  PHI
# 403976    12    11                   1               1   20171018  WAS  PHI
# 403977    73    55                   1               1   20171018  WAS  PHI
# 403978     0    -6                   1               1   20171018  WAS  PHI
# 403979     8     1                   1               1   20171018  WAS  PHI
# ...      ...   ...                 ...             ...        ...  ...  ...
# 406069     3    13                   1               1   20191123  PHI  MIA
# 406070    -4    32                   1               0   20191123  PHI  MIA
# 406071   -30    59                   1               0   20191123  PHI  MIA
# 406072    -5    62                   1               0   20191123  PHI  MIA
# 406073    -6    32                   1               0   20191123  PHI  MIA
#
# [2099 rows x 24 columns]

# %%
fig = go.Figure(data=go.Scatter(x=shots[shots['PLAYER_NAME']=='Ben Simmons']['LOC_X'],
                                y=shots[shots['PLAYER_NAME']=='Ben Simmons']['LOC_Y'],
                                mode = 'markers'
                     )
             )
fig.update_xaxes(range=[0, 7])
fig.update_yaxes(range=[0, 2.5])
fig.show()
# Out:
# <div>
#
#
#             <div id="74a560ff-3a06-4344-8dea-df1984e5b323" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("74a560ff-3a06-4344-8dea-df1984e5b323")) {
#                     Plotly.newPlot(
#                         '74a560ff-3a06-4344-8dea-df1984e5b323',
#                         [{"mode": "markers", "type": "scatter", "x": [-18, 12, 73, 0, 8, -33, 0, -64, -9, 79, 3, -44, 13, 6, 11, -19, 19, -14, 3, 21, 16, 61, -18, 38, 0, 14, 72, 29, -22, -8, -2, -49, -134, -30, -18, 26, 0, 206, 22, 15, -27, -92, -24, 33, -3, 36, -18, -27, -107, -25, -5, 2, 13, 2, -2, -6, 109, -14, 23, 6, 8, -8, 23, -141, -12, -32, 3, -11, 20, -2, -5, 66, -36, 17, 6, 0, 3, 108, 20, -7, 113, -83, 0, -11, 14, -3, 3, 85, 67, -83, 31, 129, -9, 12, 66, 9, -15, 7, 6, -62, -23, 32, -16, 29, 95, 45, 36, 3, -40, 30, 24, 106, 43, 6, 5, 7, 0, 44, 0, -116, -8, -35, -23, -112, 6, -88, 18, -49, -94, -7, -41, 19, -40, -22, -96, -7, 136, -18, -19, 43, -14, -9, 22, 1, -8, -55, 34, -90, 1, -48, -112, 1, 44, -17, 5, -22, -3, -3, 10, -51, -20, 51, 5, -39, -9, -7, 4, 27, -11, -10, -8, 1, -41, -70, 3, 18, 3, 3, 7, 16, 7, 22, -17, -38, 24, -3, -12, -12, -14, -6, -2, -4, -33, -15, 76, 4, 10, 47, 2, 3, 0, 3, 51, -119, 1, 18, 8, -16, 35, 35, -57, 2, -6, -114, 0, -96, -14, 30, -27, 82, 22, -24, -12, 15, -104, -57, 109, -18, 7, -18, 8, 19, 25, 20, 12, 11, -46, 109, -30, 22, -15, 144, 2, 0, -6, -62, -14, -22, -3, -9, 6, 3, 11, 18, 0, 22, 3, 13, 16, 3, -9, 2, 6, 9, 14, 13, -41, 40, 86, 0, 0, 2, 32, -35, 93, 18, 39, 41, 19, 29, 34, 117, 6, 10, 0, -5, 6, 3, -65, 61, -25, 16, -66, -9, -35, -33, -74, 68, 49, 1, 0, 9, 29, 37, -17, -2, -12, -2, 14, -18, -1, 33, -29, 4, -30, 0, -17, 15, 22, 0, -2, 0, 11, -58, -40, 70, 51, 9, 32, 13, -27, 25, 6, -16, 201, -7, -9, 3, -12, -12, 3, -1, -8, -155, 18, 48, 30, 37, 116, 13, 1, 128, 5, 15, -6, 57, -5, -6, -5, 18, 18, -3, -2, 35, 11, 9, 1, 14, 28, -8, 17, 50, 31, 0, -5, 4, -3, 11, -18, -136
 0, -8, 60, 3, -1, 2, 11, 0, 105, -19, -24, 25, 5, -6, -13, 93, 36, 86, -5, 4, -6, -79, -61, -85, -83, 5, 7, 92, -64, 19, -93, 12, -19, 9, -70, 20, 2, 27, 22, 16, 2, 57, 0, -50, 5, -127, 13, 32, -7, 26, 5, 52, 19, -5, -2, 39, 3, 2, 2, 39, -6, 12, 5, -23, 24, -4, 0, 60, 40, 9, -15, 13, 38, 3, -3, -23, -2, 5, -88, 3, -9,  ...

# %%
string = '2017'
string = string[0] + string[2:]
string
# Out:
# '217'

# %%
fig = go.Figure()

# Create scatter trace of text labels

# Set axes properties
fig.update_xaxes(range=[0, 4.5], zeroline=False)
fig.update_yaxes(range=[0, 4.5])

# Add circles
fig.update_layout(
    shapes=[
        # unfilled circle
        go.layout.Shape(
            type="circle",
            xref="x",
            yref="y",
            x0=1,
            y0=1,
            x1=3,
            y1=3,
            line_color="LightSeaGreen",
        ),
        # filled circle
        go.layout.Shape(
            type="circle",
            xref="x",
            yref="y",
            fillcolor="PaleTurquoise",
            x0=3,
            y0=3,
            x1=4,
            y1=4,
            line_color="LightSeaGreen",
        ),
    ]
)

# Set figure size
fig.update_layout(width=800, height=800)

fig.show()
# Out:
# <div>
#
#
#             <div id="a8e12667-51c4-4763-b53b-3bc10927549f" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8e12667-51c4-4763-b53b-3bc10927549f")) {
#                     Plotly.newPlot(
#                         'a8e12667-51c4-4763-b53b-3bc10927549f',
#                         [],
#                         {"height": 800, "shapes": [{"line": {"color": "LightSeaGreen"}, "type": "circle", "x0": 1, "x1": 3, "xref": "x", "y0": 1, "y1": 3, "yref": "y"}, {"fillcolor": "PaleTurquoise", "line": {"color": "LightSeaGreen"}, "type": "circle", "x0": 3, "x1": 4, "xref": "x", "y0": 3, "y1": 4, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "t ...

# %%
def ellipse_arc(x_center=0, y_center=0, a=1, b =1, start_angle=0, end_angle=2*np.pi, N=100, closed= False):
    t = np.linspace(start_angle, end_angle, N)
    x = x_center + a*np.cos(t)
    y = y_center + b*np.sin(t)
    path = f'M {x[0]}, {y[0]}'
    for k in range(1, len(t)):
        path += f'L{x[k]}, {y[k]}'
    if closed:
        path += ' Z'
    return path    

fig = go.Figure()

# Create a minimal trace 
fig.add_trace(go.Scatter(
    x=[0],
    y=[0.2],
    marker_size=0.1
));

fig.update_layout(width =600, height=400,
           xaxis_range=[-5.2, 5.2], 
           yaxis_range=[-3.2, 3.2],       
    shapes=[
           dict(type="path",
           path= ellipse_arc(a=5, b=3, start_angle=-np.pi/6, end_angle=3*np.pi/2, N=60),
           line_color="RoyalBlue"),
           dict(type="path",
                path = ellipse_arc(x_center=2, a= 0.5, b= 1.5, closed=True),
                fillcolor="LightPink",
                line_color="Crimson")
        ]
        );
fig.show()
# Out:
# <div>
#
#
#             <div id="1b3ebf29-b272-4e87-9295-9326e4cdc182" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1
1.2745881449242715L2.236135537386341, 1.3221800451713732L2.207707506500943, 1.3644479930317774L2.178443110795936, 1.4012217903976603L2.1484601876641376, 1.4323533621661109L2.1178794677547135, 1.4577173524853124L2.086824088833465, 1.477211629518312L2.0554190999505058, 1.4907576966918812L2.023790957911871, 1.4983010087745119L1.992067018082596, 1.4998111915108125L1.9603750215716058, 1.4952821639279135L1.9288425808633574, 1.484732162821399L1.8975966659674046, 1.468203669322168L1.8667630931549826, 1.445763237839913L1.836466018341289, 1.4175012280720027L1.8068274371534356, 1.383531441156872L1.777966693697113, 1.3439906614370039L1.75, 1.299038105676658L1.7230399680669448, 1.2488547819521572L1.6971951564311665, 1.1936427607962479L1.6725696330273574, 1.1336243615313877L1.6492625561468393, 1.0690412570682941L1.6273677751621227, 1.0001535007744375L1.6069734526286061, 0.9272384 ...

# %%
 court_shapes =[go.layout.Shape(
            type="circle",
            xref="x",
            yref="y",
            x0=-7.5,
            y0=-7.5,
            x1=7.5,
            y1=7.5,
            line_color="Black",
        ),
            go.layout.Shape(
            type="rect",
            x0=-30,
            y0=-7.5,
            x1=30,
            y1=-7.5,
            line_color="Black"),
            
            go.layout.Shape(
            type="rect",
            x0=-80,
            y0=-47.5,
            x1=80,
            y1=142.5,
            line_color="Black"),
             
            go.layout.Shape(
            type="rect",
            x0=-60,
            y0=-47.5,
            x1=60,
            y1=142.5,
            line_color="Black"),
               
            dict(type="path",
            path= ellipse_arc(y_center= 140, a=60, b=60, start_angle=0, end_angle=3*np.pi/3, N=100),
            line_color="Black"),
               
            dict(type="path",
            path= ellipse_arc(y_center= 140, a=60, b=60, start_angle=0, end_angle=-3*np.pi/3, N=100),
            line_color="Black"),
               
            go.layout.Shape(
            type="rect",
            x0=-220,
            y0=-47.5,
            x1=-220,
            y1=92.5,
            line_color="Black"),  
            
            go.layout.Shape(
            type="rect",
            x0=220,
            y0=-47.5,
            x1=220,
            y1=92.5,
            line_color="Black"),
                
            
            dict(type="path",
            path= ellipse_arc(y_center= 92.5, a=220, b=146.5, start_angle=0, end_angle=3*np.pi/3, N=100),
            line_color="Black"),
                
            go.layout.Shape(
            type="rect",
            x0=-250,
            y0=-47.5,
            x1=250,
            y1=422.5,
            line_color="Black"),
             
            dict(type="path",
            path= ellipse_arc(a=40, b=40, start_angle=0, end_angle=3*np.pi/3, N=100),
            line_color="Black"),
                
            dict(type="path",
            path= ellipse_arc(y_center= 422.5, a=60, b=60, start_angle=0, end_angle=-3*np.pi/3, N=100),
            line_color="Black"),
            
            dict(type="path",
            path= ellipse_arc(y_center= 422.5, a=20, b=20, start_angle=0, end_angle=-3*np.pi/3, N=100),
            line_color="Black"),   
               ]

# %%
N = 1000
t = np.linspace(0, 10, 100)
y = np.sin(t)

layout = go.Layout(
        shapes=court_shapes)
fig = go.Figure(data=go.Scatter(x=t, y=y, mode='markers',
                               ),
               layout=layout)

fig.show()
# Out:
# <div>
#
#
#             <div id="fff789c8-dc46-4278-b49c-01150d426037" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
.17180416602812L51.47900479409862, 170.82064349440438L50.47521196987087, 172.43844904733584L49.42059488578997, 174.02359183176625L48.31621545186352, 175.5744757432784L47.16318568456725, 177.08953917323632L45.962666587138685, 178.56725658119234L44.715866980545286, 180.0061400309775L43.42404228630421, 181.40474068892672L42.088493262379274, 182.76165028273178L40.71056469342793, 184.07550251945202L39.29164403671711, 185.3449744612555L37.83316002507135, 186.5687878575054L36.33658122826, 187.74571043184994L34.8034145742719, 188.87455712302014L33.235203831966615, 189.95419127808628L31.633528056630148, 190.98352579697087L29.999999999999996, 191.96152422706632L28.336264486360964, 192.88720180685493L26.64399675634644, 193.75962645748015L24.924900780113187, 194.5779197212711L23.180707541587715, 195.3412576462749L21.413173295512312, 196.04887161590642L19.624077799045292, 196.7000491228801L17.815222519696494, 197.29413448664442L15.988428821402096, 197.83052951359653L14.145536130565636, 198.3086940994125L12.288400083911437, 198.72814677288673L10.418890660015824, 199.0884651807325L8.538890296397106, 199.38928651285596L6.650291994060666, 199.63030786767524L4.754997411407307, 199.81128655711655L2.854914949424531, 199.9320403509805L0.9519578300884759, 199.9924476604325L-0.9519578300884817, 199.9924476604325L-2.8549149494245367, 199.9320403509805L-4.754997411407313, 199.81128655711655L-6.650291994060659, 199.63030786767524L-8.538890296397113, 199.38928651285596L-10.418890660015819, 199.0884651807325L-12.288400083911444, 198.72814677288673L-14.145536130565631, 198.3086940994125L-15.988428821402103, 197.83052951359653L-17.815222519696487, 197.29413448664442L-19.6240777990453, 196.7000491228801L-21.41317329551231, 196.04887161590642L-23.180707541587722, 195.34125764627487L-24.92490078011318, 194.57791972127112L-26.643996756346446, 193.75962645748015L-28.336264486360957, 192.88720180685493L-30.000000000000007, 191.96152422706632L-31.633528056630148, 190.98352579697087L-33.235203831966615, 189.95419127808628L-34.80341457427188, 188.87455712302017L-36.33658122826001, 187.74571043184991L-37.83316002507135, 186.5687878575054L-39.2916440367171, 185.3449744612555L-40.710564693427926, 184.07550251945202L-42.08849326237928, 182.76165028273178L-43.424042286304214, 181.40474068892672L-44.71586698054528, 180.0061400309775L-45.96266658713867, 178.56725658119237L-47

# %%
def shot_chart(name, year=''):    
    if year:
        year_clean = '00' + year[0] + year[2:]
        player = shots[(shots.PLAYER_NAME == name) & (shots.GAME_ID.str.contains(year_clean))]
    else:
        player= shots[shots.PLAYER_NAME == name]

    missed_shot_trace = go.Scattergl(
            x = player[player.SHOT_MADE_FLAG == 0]['LOC_X'],
            y = player[player.SHOT_MADE_FLAG == 0]['LOC_Y'],
            mode = 'markers',
            name = 'Make',
            marker= dict(color='blue', symbol='x', size=8, line={'width':1}, opacity=0.7),
            text = [str(sd) for sd in player[player.SHOT_MADE_FLAG == 0]['ACTION_TYPE']],
            hoverinfo = 'text'
        )
    made_shot_trace = go.Scattergl(
        x = player[player.SHOT_MADE_FLAG == 1]['LOC_X'],
        y = player[player.SHOT_MADE_FLAG == 1]['LOC_Y'],
        mode = 'markers',
        name='Make',
        marker= dict(color='red', symbol='circle', size=8, line={'width':1}, opacity=0.7),
        text = [str(sd) for sd in player[player.SHOT_MADE_FLAG == 1]['ACTION_TYPE']],
        hoverinfo = 'text'
    )

    
   
    data = [missed_shot_trace, made_shot_trace]
    layout = go.Layout(
        title= name + ' Shot Chart ' + year,
        showlegend =True,
        xaxis={'showgrid':False, 'range':[-250,250]},
        yaxis={'showgrid':False, 'range':[422.5,-47.5]},
        height = 600,
        width = 650,
        shapes=court_shapes)

    fig = go.Figure(data=data, layout=layout)
    fig.show()

# %%
shot_chart('Ben Simmons', '2017')
# Out:
# <div>
#
#
#             <div id="1479e4d9-fe3d-4674-8bcc-a798b08e864b" class="plotly-graph-div" style="height:600px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1479e4d9-fe3d-4674-8bcc-a798b08e864b")) {
#                     Plotly.newPlot(
#                         '1479e4d9-fe3d-4674-8bcc-a798b08e864b',
#                         [{"hoverinfo": "text", "marker": {"color": "blue", "line": {"width": 1}, "opacity": 0.7, "size": 8, "symbol": "x"}, "mode": "markers", "name": "Make", "text": ["Layup Shot", "Driving Floating Jump Shot", "Tip Layup Shot", "Turnaround Hook Shot", "Driving Floating Jump Shot", "Floating Jump shot", "Driving Layup Shot", "Turnaround Jump Shot", "Layup Shot", "Layup Shot", "Driving Layup Shot", "Layup Shot", "Layup Shot", "Tip Layup Shot", "Layup Shot", "Running Layup Shot", "Jump Shot", "Pullup Jump shot", "Running Layup Shot", "Tip Layup Shot", "Running Jump Shot", "Driving Layup Shot", "Running Layup Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Finger Roll Layup Shot", "Pullup Jump shot", "Turnaround Hook Shot", "Jump Shot", "Driving Finger Roll Layup Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Layup Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Pullup Jump shot", "Driving Layup Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Driving Reverse Layup Shot", "Turnaround Hook Shot", "Layup Shot", "Driving Layup Shot", "Jump Shot", "Hook Shot", "Driving Layup Shot", "Jump Shot", "Layup Shot", "Layup Shot", "Turnaround Jump Shot", "Tip Layup Shot", "Step Back Jump shot", "Running Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Driving Hook Shot", "Fadeaway Jump Shot", "Pullup Jump shot", "Hook Shot", "Floating Jump shot", "Pullup Jump shot", "Step Back Jump shot", "Jump Shot", "Pullup Jump shot", "Hook Shot", "Jump Shot", "Hook Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Floating Jump shot", "Jump Shot", "Floating Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Fadeaway shot", "Layup Shot", "Layup Shot", "Hook Shot", "Jump Shot", "Turnaround Fadeaway shot", "Layup Shot", "Alley Oop Dunk Shot", "Floating Jump shot", "Jump Bank Shot", "Running Jump Shot", "Dunk Shot", "Hook Shot", "Hook Shot", "Floating Jump shot", "Finger Roll Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Putback Dunk Shot", "Running Jump Shot", "Turnaround Hook Shot", "Driving Floating Jump Shot", "Driving Layup Shot", "Layup Shot", "Jump Shot", "Layup Shot", "Driving Finger Roll Layup Shot", "Driving Layup Shot", "Turnaround Hook Shot", "Turnaround Hook Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Driving Hook Shot", "Layup Shot", "Turnaround Hook Shot", "Layup Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Running Layup Shot", "Layup Shot", "Driving Finger Roll Layup Shot", "Driving Layup Shot", "Driving Hook Shot", "Driving Floating Jump Shot", "Floating Jump shot", "Floating Jump shot", "Jump Bank Shot", "Turnaround Jump Shot", "Driving Layup Shot", "Driving Layup Shot", "Driving Floating Jump Shot", "Running Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Driving Hook Shot", "Driving Hook Shot", "Driving Finger Roll Layup Shot", "Pullup Jump shot", "Turnaround Fadeaway shot", "Turnaround Hook Shot", "Layup Shot", "Driving Hook Shot", "Running Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Driving Layup Shot", "Driving Floating Jump Shot", "Jump Shot", "Layup Shot", "Reverse Layup Shot", "Driving Finger Roll Layup Shot", "Pullup Jump shot", "Driving Layup Shot", "Driving Layup Shot", "Turnaround Hook Shot", "Pullup Jump shot", "Floating Jump shot", "Alley Oop Dunk Shot", "Driving Finger Roll Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Driving Floating Jump Shot", "Driving Hook Shot", "Driving Floating Bank Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Layup Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Running Jump Shot", "Reverse Layup Shot", "Turnaround Hook Shot", "Floating Jump shot", "Floating Jump shot", "Driving Layup Shot", "Driving Layup Shot", "Jump Shot", "Driving Floating Bank Jump Shot", "Layup Shot", "Layup Shot", "Driving Layup Shot", "Layup Shot", "Jump Shot", "Turnaround Fadeaway shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jum ...

# %%
def optimal_defense(name, year=''):

# %%
def similar_shooters(name, year=''):
        if year:
            year_clean = '00' + year[0] + year[2:]
            df = shots[shots['GAME_ID'].str.contains(year_clean)]
        else:
            df
        
        
        dummy = pd.get_dummies(df, columns=['ACTION_TYPE', 'SHOT_TYPE'], prefix=['',''], prefix_sep=['',''])
        
        attempts = pd.DataFrame(dummy.groupby('PLAYER_NAME')['SHOT_ATTEMPTED_FLAG'].agg(sum))
        to_drop = attempts[attempts['SHOT_ATTEMPTED_FLAG'] < 250]
        
        
        shot_breakdown = dummy.drop(labels=['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID',
       'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
       'SECONDS_REMAINING', 'EVENT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA',
       'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y',
       'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', '2PT Field Goal', '3PT Field Goal'], axis=1)
        
        grouped = shot_breakdown.groupby('PLAYER_NAME').agg('mean')
        grouped.drop(to_drop.index, inplace=True)
        
        col = grouped.idxmax(axis=1)[name]
        
        sorted_ = grouped.sort_values(col)
        
        head = pd.DataFrame(sorted_.loc[:name, col].tail())
        tail = pd.DataFrame(sorted_.loc[name:, col].head())
        
        final = pd.concat([head,tail]).reset_index().drop_duplicates()
    
        data = go.Bar(x=final['PLAYER_NAME'].values, 
                  y=final[col].values)
        layout = go.Layout(
                        title =  'Players who shoot a similar percentage of {} top shot '.format(name) + year)
    
        fig = go.Figure(data=data, layout = layout)
        fig.show()

# %%
similar_shooters('Ben Simmons', '2017')
# Out:
# <div>
#
#
#             <div id="dfc673bf-f7bc-4b8e-9224-693ebd17521c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dfc673bf-f7bc-4b8e-9224-693ebd17521c")) {
#                     Plotly.newPlot(
#                         'dfc673bf-f7bc-4b8e-9224-693ebd17521c',
#                         [{"type": "bar", "x": ["Jrue Holiday", "Brandon Ingram", "Isaiah Thomas", "De'Aaron Fox", "Ben Simmons", "Kris Dunn", "Rondae Hollis-Jefferson", "Eric Gordon", "Kent Bazemore"], "y": [0.1342443729903537, 0.13534822601839686, 0.13539192399049882, 0.1355081555834379, 0.13627254509018036, 0.13813813813813813, 0.14226519337016574, 0.14329896907216494, 0.14349112426035504]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
similar_shooters('James Harden', '2018')
# Out:
# <div>
#
#
#             <div id="9f64f822-00da-49c2-9dce-4a94be7b7c7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f64f822-00da-49c2-9dce-4a94be7b7c7d")) {
#                     Plotly.newPlot(
#                         '9f64f822-00da-49c2-9dce-4a94be7b7c7d',
#                         [{"type": "bar", "x": ["Allonzo Trier", "Brandon Knight", "Troy Daniels", "Luka Doncic", "James Harden"], "y": [0.11196911196911197, 0.11538461538461539, 0.12363636363636364, 0.16104553119730186, 0.3074908328968046]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
def shot_breakdown(name, year = ''):    
    
    if year:
        year_clean = '00' + year[0] + year[2:]
        player = shots[(shots.PLAYER_NAME == name) & (shots.GAME_ID.str.contains(year_clean))]
    else:
        player= shots[shots.PLAYER_NAME == name]
        
    player_dummy = pd.get_dummies(player, columns=['ACTION_TYPE', 'SHOT_TYPE'], prefix=['',''], prefix_sep=['',''])
    
    shot_breakdown = player_dummy.drop(labels=['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
       'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
       'SECONDS_REMAINING', 'EVENT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA',
       'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y',
       'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', '2PT Field Goal', '3PT Field Goal'], axis=1).mean()
    
    top_10_types = shot_breakdown.sort_values(ascending=False)[:10]
    
    data = go.Bar(x=top_10_types.index, 
                  y=top_10_types.values)
    layout = go.Layout(
                        title = name + ' Percentage of Shots Taken ' + year)
    
    fig = go.Figure(data=data, layout = layout)
    fig.show()

# %%
shot_breakdown('Ben Simmons', '2017')
# Out:
# <div>
#
#
#             <div id="f757b3d8-ab6f-4d1c-953a-e6248a3988f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f757b3d8-ab6f-4d1c-953a-e6248a3988f2")) {
#                     Plotly.newPlot(
#                         'f757b3d8-ab6f-4d1c-953a-e6248a3988f2',
#                         [{"type": "bar", "x": ["Driving Layup Shot", "Jump Shot", "Layup Shot", "Pullup Jump shot", "Driving Dunk Shot", "Turnaround Hook Shot", "Dunk Shot", "Driving Finger Roll Layup Shot", "Driving Hook Shot", "Driving Floating Jump Shot"], "y": [0.13627254509018036, 0.08917835671342686, 0.08316633266533066, 0.06813627254509018, 0.045090180360721446, 0.045090180360721446, 0.03807615230460922, 0.036072144288577156, 0.036072144288577156, 0.03406813627254509]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
shot_chart('Chris Paul', '2017')
shot_breakdown('Chris Paul', '2017')
# Out:
# <div>
#
#
#             <div id="5e476064-ed73-49c3-842e-d484387dc166" class="plotly-graph-div" style="height:600px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5e476064-ed73-49c3-842e-d484387dc166")) {
#                     Plotly.newPlot(
#                         '5e476064-ed73-49c3-842e-d484387dc166',
#                         [{"hoverinfo": "text", "marker": {"color": "blue", "line": {"width": 1}, "opacity": 0.7, "size": 8, "symbol": "x"}, "mode": "markers", "name": "Make", "text": ["Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Running Pull-Up Jump Shot", "Jump Shot", "Floating Jump shot", "Step Back Jump shot", "Running Jump Shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Floating Jump shot", "Step Back Jump shot", "Jump Shot", "Fadeaway Jump Shot", "Driving Floating Jump Shot", "Jump Shot", "Turnaround Fadeaway shot", "Layup Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Step Back Jump shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Driving Layup Shot", "Jump Shot", "Step Back Jump shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Jump Shot", "Driving Floating Jump Shot", "Jump Shot", "Step Back Jump shot", "Jump Shot", "Fadeaway Jump Shot", "Step Back Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Floating Jump Shot", "Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Floating Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Floating Jump shot", "Step Back Jump shot", "Pullup Jump shot", "Driving Layup Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Fadeaway Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Driving Floating Jump Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Driving Floating Jump Shot", "Floating Jump shot", "Jump Shot", "Running Layup Shot", "Jump Shot", "Floating Jump shot", "Running Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Driving Layup Shot", "Step Back Jump shot", "Jump Shot", "Driving Floating Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Bank Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Step Back Jump shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Step Back Jump shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Floating Jump shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Fadeaway Jump Shot", "Jump Shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Running Layup Shot", "Driving Layup Shot", "Pullup Jump shot", "Driving Floating Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Pullu ...
# <div>
#
#
#             <div id="01b760c1-599b-4e90-8438-e55b86275d7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("01b760c1-599b-4e90-8438-e55b86275d7e")) {
#                     Plotly.newPlot(
#                         '01b760c1-599b-4e90-8438-e55b86275d7e',
#                         [{"type": "bar", "x": ["Jump Shot", "Pullup Jump shot", "Step Back Jump shot", "Fadeaway Jump Shot", "Driving Layup Shot", "Driving Floating Jump Shot", "Floating Jump shot", "Driving Finger Roll Layup Shot", "Running Layup Shot", "Layup Shot"], "y": [0.4273182957393484, 0.21804511278195488, 0.08646616541353383, 0.06390977443609022, 0.05263157894736842, 0.03884711779448621, 0.021303258145363407, 0.016290726817042606, 0.013784461152882205, 0.013784461152882205]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
shot_chart('JJ Redick', '2017')
shot_breakdown('JJ Redick', '2017')
# Out:
# <div>
#
#
#             <div id="92974da5-740a-4bbc-b230-99b2231b7037" class="plotly-graph-div" style="height:600px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92974da5-740a-4bbc-b230-99b2231b7037")) {
#                     Plotly.newPlot(
#                         '92974da5-740a-4bbc-b230-99b2231b7037',
#                         [{"hoverinfo": "text", "marker": {"color": "blue", "line": {"width": 1}, "opacity": 0.7, "size": 8, "symbol": "x"}, "mode": "markers", "name": "Make", "text": ["Fadeaway Jump Shot", "Driving Layup Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Fadeaway Jump Shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Jump Shot", "Running Pull-Up Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Running Pull-Up Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Running Pull-Up Jump Shot", "Layup Shot", "Step Back Jump shot", "Running Layup Shot", "Jump Shot", "Step Back Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Running Layup Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Pullup Jump shot", "Jump Shot", "Driving Reverse Layup Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Running Pull-Up Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Cutting Layup Shot", "Cutting Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Running Pull-Up Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Step Back Jump shot", "Jump Shot", "Pullup Jump shot", "Pullup Jump shot", "Driving Layup Shot", "Jump Shot", "Pullup Jump shot", "Fadeaway Jump Shot", "Floating Jump shot", "Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Re ...
# <div>
#
#
#             <div id="713291ce-9111-4d48-9ff8-fa0b8173a0ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("713291ce-9111-4d48-9ff8-fa0b8173a0ff")) {
#                     Plotly.newPlot(
#                         '713291ce-9111-4d48-9ff8-fa0b8173a0ff',
#                         [{"type": "bar", "x": ["Jump Shot", "Pullup Jump shot", "Driving Layup Shot", "Running Pull-Up Jump Shot", "Cutting Layup Shot", "Layup Shot", "Step Back Jump shot", "Running Jump Shot", "Driving Floating Jump Shot", "Fadeaway Jump Shot"], "y": [0.6166097838452788, 0.20705346985210465, 0.03185437997724687, 0.017064846416382253, 0.017064846416382253, 0.015927189988623434, 0.01478953356086462, 0.011376564277588168, 0.011376564277588168, 0.011376564277588168]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
shot_chart('LaMarcus Aldridge', '2017')
shot_breakdown('LaMarcus Aldridge', '2017')
# Out:
# <div>
#
#
#             <div id="16b4bc6c-5465-4587-99ce-71d5de208366" class="plotly-graph-div" style="height:600px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16b4bc6c-5465-4587-99ce-71d5de208366")) {
#                     Plotly.newPlot(
#                         '16b4bc6c-5465-4587-99ce-71d5de208366',
#                         [{"hoverinfo": "text", "marker": {"color": "blue", "line": {"width": 1}, "opacity": 0.7, "size": 8, "symbol": "x"}, "mode": "markers", "name": "Make", "text": ["Jump Shot", "Jump Shot", "Tip Layup Shot", "Floating Jump shot", "Turnaround Jump Shot", "Jump Shot", "Tip Layup Shot", "Jump Shot", "Step Back Jump shot", "Jump Shot", "Jump Bank Shot", "Reverse Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Driving Layup Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Hook Shot", "Jump Bank Shot", "Turnaround Jump Shot", "Cutting Finger Roll Layup Shot", "Jump Shot", "Putback Layup Shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Jump Shot", "Alley Oop Layup shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Layup Shot", "Fadeaway Jump Shot", "Alley Oop Layup shot", "Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Turnaround Fadeaway Bank Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Turnaround Jump Shot", "Tip Layup Shot", "Jump Shot", "Jump Shot", "Hook Shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Turnaround Fadeaway shot", "Jump Shot", "Turnaround Jump Shot", "Hook Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Hook Shot", "Jump Shot", "Putback Layup Shot", "Putback Layup Shot", "Layup Shot", "Jump Shot", "Turnaround Fadeaway Bank Jump Shot", "Jump Shot", "Jump Shot", "Dunk Shot", "Turnaround Fadeaway shot", "Tip Dunk Shot", "Turnaround Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Fadeaway Jump Shot", "Hook Shot", "Turnaround Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Cutting Layup Shot", "Jump Shot", "Turnaround Jump Shot", "Pullup Jump shot", "Driving Layup Shot", "Pullup Jump shot", "Turnaround Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Driving Layup Shot", "Turnaround Hook Shot", "Turnaround Fadeaway shot", "Layup Shot", "Hook Shot", "Putback Layup Shot", "Turnaround Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Hook Shot", "Turnaround Jump Shot", "Jump Shot", "Turnaround Fadeaway shot", "Turnaround Jump Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Jump Shot", "Hook Shot", "Jump Shot", "Jump Shot", "Hook Shot", "Turnaround Jump Shot", "Step Back Jump shot", "Jump Shot", "Turnaround Jump Shot", "Cutting Layup Shot", "Pullup Jump shot", "Step Back Jump shot", "Jump Shot", "Turnaround Hook Shot", "Turnaround Jump Shot", "Layup Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Turnaround Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Fadeaway Bank Jump Shot", "Turnaround Fadeaway shot", "Jump Shot", "Jump Shot", "Driving Floating Jump Shot", "Turnaround Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Hook Shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Turnaround Jump Shot", "Pullup Jump shot", "Jump Shot", "Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Fadeaway Jump Shot", "Jump Shot", "Jump Shot", "Layup Shot", "Fadeaway Jump Shot", "Turnaround Fadeaway shot", "Jump Shot", "Cutting Layup Shot", "Turnaround Jump Shot", "Turnaround Fadeaway shot", "Jump Shot", "Jump Shot", "Jump Shot", "Jump Bank Shot", "Fadeaway Jump Shot", "Jump Shot", "Layup Shot", "Jump Shot", "Turnaround Jump Shot", "Turnaround Hook Shot", "Reverse Layup Shot", "Jump Shot", "Layup Shot", "Turnaround Jump Shot", "Driving Hook Shot", "Turnaround Jump Shot", "Jump Bank Shot", "Layup Shot", "Driving Floating Jump Shot", "Jump Shot", "Jump Shot", "Turnaround Fadeaway shot", "Tip Layup Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Jump ...
# <div>
#
#
#             <div id="1156fb0c-0bcd-4259-8631-f53cfd13f805" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1156fb0c-0bcd-4259-8631-f53cfd13f805")) {
#                     Plotly.newPlot(
#                         '1156fb0c-0bcd-4259-8631-f53cfd13f805',
#                         [{"type": "bar", "x": ["Jump Shot", "Turnaround Jump Shot", "Layup Shot", "Turnaround Fadeaway shot", "Putback Layup Shot", "Hook Shot", "Turnaround Hook Shot", "Pullup Jump shot", "Fadeaway Jump Shot", "Driving Layup Shot"], "y": [0.25315515961395696, 0.13808463251670378, 0.08537490720118783, 0.08314773570898293, 0.050482553823311065, 0.04899777282850779, 0.03637713437268003, 0.03414996288047513, 0.02969561989606533, 0.02746844840386043]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
shot_chart('James Harden', '2018')
shot_breakdown('James Harden', '2018')
# Out:
# <div>
#
#
#             <div id="805c8c81-d7d9-4e69-a192-7ebd18276091" class="plotly-graph-div" style="height:600px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("805c8c81-d7d9-4e69-a192-7ebd18276091")) {
#                     Plotly.newPlot(
#                         '805c8c81-d7d9-4e69-a192-7ebd18276091',
#                         [{"hoverinfo": "text", "marker": {"color": "blue", "line": {"width": 1}, "opacity": 0.7, "size": 8, "symbol": "x"}, "mode": "markers", "name": "Make", "text": ["Driving Finger Roll Layup Shot", "Step Back Jump shot", "Step Back Jump shot", "Driving Finger Roll Layup Shot", "Driving Floating Jump Shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Driving Layup Shot", "Layup Shot", "Jump Shot", "Jump Shot", "Step Back Jump shot", "Pullup Jump shot", "Layup Shot", "Reverse Layup Shot", "Driving Layup Shot", "Step Back Jump shot", "Step Back Jump shot", "Step Back Jump shot", "Step Back Jump shot", "
class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4a1ce3f-d36a-4354-b19e-8b391fbcfa99")) {
#                     Plotly.newPlot(
#                         'a4a1ce3f-d36a-4354-b19e-8b391fbcfa99',
#                         [{"type": "bar", "x": ["Step Back Jump shot", "Jump Shot", "Driving Layup Shot", "Driving Floating Jump Shot", "Pullup Jump shot", "Driving Finger Roll Layup Shot", "Layup Shot", "Running Layup Shot", "Floating Jump shot", "Driving Floating Bank Jump Shot"], "y": [0.3074908328968046, 0.18281822943949713, 0.16972236773179675, 0.08905185961236249, 0.0785751702462022, 0.04138292299633316, 0.030382399161864852, 0.019381875327396544, 0.014667365112624411, 0.014143530644316397]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
sim17 = shots[(shots['PLAYER_NAME'] == 'Ben Simmons') & (shots.GAME_ID.str.contains('00217'))]
sim_dummy = pd.get_dummies(sim17, columns=['ACTION_TYPE','SHOT_TYPE'], prefix=['',''], prefix_sep=['',''])
sim_dummy.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA',
#        'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y',
#        'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM',
#        'Alley Oop Dunk Shot', 'Alley Oop Layup shot', 'Cutting Dunk Shot',
#        'Cutting Finger Roll Layup Shot', 'Cutting Layup Shot',
#        'Driving Dunk Shot', 'Driving Finger Roll Layup Shot',
#        'Driving Floating Bank Jump Shot', 'Driving Floating Jump Shot',
#        'Driving Hook Shot', 'Driving Layup Shot', 'Driving Reverse Dunk Shot',
#        'Driving Reverse Layup Shot', 'Dunk Shot', 'Fadeaway Jump Shot',
#        'Finger Roll Layup Shot', 'Floating Jump shot', 'Hook Shot',
#        'Jump Bank Shot', 'Jump Shot', 'Layup Shot', 'Pullup Jump shot',
#        'Putback Dunk Shot', 'Putback Layup Shot', 'Reverse Dunk Shot',
#        'Reverse Layup Shot', 'Running Alley Oop Dunk Shot',
#        'Running Alley Oop Layup Shot', 'Running Dunk Shot',
#        'Running Finger Roll Layup Shot', 'Running Jump Shot',
#        'Running Layup Shot', 'Running Pull-Up Jump Shot',
#        'Running Reverse Dunk Shot', 'Running Reverse Layup Shot',
#        'Step Back Bank Jump Shot', 'Step Back Jump shot', 'Tip Dunk Shot',
#        'Tip Layup Shot', 'Turnaround Bank Hook Shot',
#        'Turnaround Fadeaway shot', 'Turnaround Hook Shot',
#        'Turnaround Jump Shot', '2PT Field Goal', '3PT Field Goal'],
#       dtype='object')

# %%
shot_breakdown = sim_dummy.drop(labels=['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
       'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
       'SECONDS_REMAINING', 'EVENT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA',
       'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y',
       'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', '2PT Field Goal', '3PT Field Goal'], axis=1).mean()

# %%
shot_breakdown.sort_values(ascending=False)[:10]
# Out:
# Driving Layup Shot                0.136273
# Jump Shot                         0.089178
# Layup Shot                        0.083166
# Pullup Jump shot                  0.068136
# Driving Dunk Shot                 0.045090
# Turnaround Hook Shot              0.045090
# Dunk Shot                         0.038076
# Driving Finger Roll Layup Shot    0.036072
# Driving Hook Shot                 0.036072
# Driving Floating Jump Shot        0.034068
# dtype: float64
